# %% [markdown]
# ### The commands that we used in this project :
#
# * head() - It shows the first N rows in the data (by default, N=5).
# * tail () - It shows the last N rows in the data (by default, N=5).
# * shape - It shows the total no. of rows and no. of columns of the dataframe.
# * size - To show No. of total values(elements) in the dataset.
# * columns - To show each Column Name.
# * dtypes - To show the data-type of each column.
# * info() - To show indexes, columns, data-types of each column, memory at once.
# * value_counts - In a column, it shows all the unique values with their count. It can be applied on a single column only.
# * unique() - It shows the all unique values of the series.
# * nunique() - It shows the total no. of unique values in the series.
# * duplicated( ) - To check row wise and detect the Duplicate rows.
# * isnull( ) - To show where Null value is present.
# * dropna( ) - It drops the rows that contains all missing values.
# * isin( ) - To show all records including particular elements.
# * str.contains( ) - To get all records that contains a given string.
# * str.split( ) - It splits a column's string into different columns.
# * to_datetime( ) - Converts the data-type of Date-Time Column into datetime[ns] datatype.
# * dt.year.value_counts( ) - It counts the occurrence of all individual years in Time column.
# * groupby( ) - Groupby is used to split the data into groups based on some criteria.
# * sns.countplot(df['Col_name']) - To show the count of all unique values of any column in the form of bar graph.
# * max( ), min( ) - It shows the maximum/minimum value of the series.
# * mean( ) - It shows the mean value of the series.

# %% [markdown]
# ## Required libraries

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
sns.set_theme(context = 'poster' , style = 'ticks' , palette = 'magma' , font_scale = 0.7 , rc = {'figure.figsize':[22, 10]})

# %%
df = pd.read_csv('Netflix Dataset.csv')

# %% [markdown]
# ### .head()

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %% [markdown]
# ### .tail()

# %%
df.tail()
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %% [markdown]
# ### .shape

# %%
df.shape
# Out:
# (7789, 11)

# %% [markdown]
# ### .size

# %%
df.size
# Out:
# 85679

# %% [markdown]
# ## .columns

# %%
df.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %% [markdown]
# ### .dtypes

# %%
df.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %% [markdown]
# ### .info()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %% [markdown]
# ### Q. 1) Is there any Duplicate Record in this dataset ? If yes, then remove the duplicate records.

# %%
df.shape
# Out:
# (7789, 11)

# %%
df[df.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
df.duplicated().sum() # it has 2 duplicated rows
# Out:
# 2

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (7787, 11)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description]
# Index: []

# %% [markdown]
# ### Q. 2) Is there any Null Value present in any column ? Show with Heat-map.

# %%
df.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Q. 3) For 'House of Cards', what is the Show Id and Who is the Director of this show ?

# %%
#filtering
display(df[df['Title'] == 'House of Cards'])
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
# .isin()
df[df['Title'].isin(['House of Cards'])]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %%
# .str.contains()
df[df['Title'].str.contains('House of Cards')]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# ### Q. 4) In which year the highest number of the TV Shows & Movies were released ? Show with Bar Graph.

# %%
df.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
df.Release_Date = pd.to_datetime(df.Release_Date)

# %%
df.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date    datetime64[ns]
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# dtype: object

# %%
df['Year'] = df.Release_Date.dt.year

# %%
x = df.Year.value_counts() ## 2019 is the most year has releasd tv shows and movies
x
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: Year, dtype: int64

# %%
sns.countplot(data=df,x='Year',hue='Category',order=x.index,palette='icefire')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='count'>

# %%
px.pie(data_frame=df,names='Year',opacity=1,color_discrete_sequence=px.colors.qualitative.Bold,height=400)
# Out:
# <div>                            <div id="96518c57-8356-4a40-9a82-91d864b53abf" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("96518c57-8356-4a40-9a82-91d864b53abf")) {                    Plotly.newPlot(                        "96518c57-8356-4a40-9a82-91d864b53abf",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Year=%{label}<extra></extra>","labels":[2020.0,2016.0,2018.0,2017.0,2020.0,2017.0,2020.0,2019.0,2019.0,2017.0,2017.0,2018.0,2019.0,2019.0,2020.0,2019.0,2019.0,2018.0,2019.0,2018.0,2018.0,2018.0,2018.0,2018.0,2020.0,2016.0,2020.0,2020.0,2020.0,2020.0,2020.0,2020.0,2020.0,2017.0,2019.0,2016.0,2019.0,2019.0,2019.0,2019.0,2017.0,2018.0,2017.0,2020.0,2018.0,2017.0,2017.0,2017.0,2019.0,2017.0,2019.0,2020.0,2018.0
# ...

# %% [markdown]
# ### Q. 5) How many Movies & TV Shows are in the dataset ? Show with Bar Graph.

# %%
df.Category.value_counts()
# Out:
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
px.pie(data_frame=df,names='Category',opacity=1,color_discrete_sequence=px.colors.qualitative.Bold,height=400)
# Out:
# <div>                            <div id="73d50a0e-d91e-4048-97b6-142cfb755f0e" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("73d50a0e-d91e-4048-97b6-142cfb755f0e")) {                    Plotly.newPlot(                        "73d50a0e-d91e-4048-97b6-142cfb755f0e",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Category=%{label}<extra></extra>","labels":["TV Show","Movie","Movie","Movie","Movie","TV Show","Movie","Movie","Movie","Movie","Movie","TV Show","TV Show","Movie","Movie","Movie","TV Show","Movie","Movie","Movie","Movie","Movie","Movie","Movie","TV Show","Movie","TV Show","Movie","Movie","TV Show","Movie","Movie","Movie","Movie","Movie","Movie","Movie","Movie","TV Show","Movie","Movie","Movie","Movie","Mov
# ...

# %%
sns.countplot(data=df,x='Category',palette='icefire')
sns.despine()

# %% [markdown]
# ### Q. 6) Show all the Movies that were released in year 2000.

# %%
df[df.Year == 2000]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Year]
# Index: []

# %%
df.Year.value_counts() #it seems that there is nothing released in 2000
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: Year, dtype: int64

# %% [markdown]
# ### Q. 7) Show only the Titles of all TV Shows that were released in India only.

# %%
df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
#
#                                                 Cast Country Release_Date  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...  Brazil   2020-08-14
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...  Mexico   2016-12-23
#
#   Rating   Duration                                               Type  \
# 0  TV-MA  4 Seasons  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1  TV-MA     93 min                       Dramas, International Movies
#
#                                          Description    Year
# 0  In a future where the elite inhabit an island ...  2020.0
# 1  After a devastating earthquake hits Mexico Cit...  2016.0

# %%
india = df[df.Country == 'India']
india.head(20)
# Out:
#     Show_Id Category                         Title  \
# 8        s9    Movie                           706
# 9       s10    Movie                          1920
# 18      s19    Movie                        15-Aug
# 20      s21    Movie          ​​Kuch Bheege Alfaaz
# 21      s22    Movie                  ​Goli Soda 2
# 22      s23    Movie            ​Maj Rati ​​Keteki
# 23      s24    Movie                   ​Mayurakshi
# 59      s60    Movie               1000 Rupee Note
# 78      s79    Movie                      2 States
# 86      s87  TV Show  21 Sarfarosh: Saragarhi 1897
# 90      s91    Movie                      25 Kille
# 100    s101    Movie                      3 Idiots
# 129    s130    Movie                         6-5=2
# 132    s133  TV Show                     7 (Seven)
# 136    s137    Movie                  7 Khoon Maaf
# 143    s144    Movie                         90 ML
# 150    s151    Movie        A Billion Colour Story
# ...

# %%
india[india.Category == 'TV Show'][['Title']].T
# Out:
#                                86         132           340           364   \
# Title  21 Sarfarosh: Saragarhi 1897  7 (Seven)  Agent Raghav  Akbar Birbal
#
#                       533                          534   \
# Title  Anjaan: Rural Myths  Anjaan: Special Crimes Unit
#
#                               686                         698            750   \
# Title  Bad Boy Billionaires: India  Badalte Rishton Ki Dastaan  Bard of Blood
#
#          856   ...         5888            5959  \
# Title  Betaal  ...  Super Bheem  Taj Mahal 1989
#
#                                         6037       6039         6197  \
# Title  Th Eena Meena Deeka Chase Comedy Show  Thackeray  The Calling
#
#                        6249                                6400  \
# Title  The Creative Indians  The Golden Years with Javed Akhtar
#
#                          6469        7294             7705
# Title  The House That Made Me  Typewriter  Yeh Meri Family
#
# [1 rows x 71 columns]

# %% [markdown]
# ### Q. 8) Show Top 10 Directors, who gave the highest number of TV Shows & Movies to Netflix ?

# %%
df.Director.value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Hakan Algül                8
# Name: Director, dtype: int64

# %% [markdown]
# ### Q. 9) Show all the Records, where "Category is Movie and Type is Comedies" or "Country is United Kingdom".

# %%
df[((df['Category'] == 'Movie') & (df['Type'] == 'Comedies')) | (df['Country'] == 'United Kingdom')]
# Out:
#      Show_Id Category                   Title          Director  \
# 19       s20    Movie                     '89               NaN
# 33       s34    Movie            #realityhigh  Fernando Lebrija
# 58       s59  TV Show             100% Hotter               NaN
# 72       s73    Movie                17 Again       Burr Steers
# 82       s83    Movie     2036 Origin Unknown     Hasraf Dulull
# ...      ...      ...                     ...               ...
# 7670   s7669  TV Show  World War II in Colour               NaN
# 7671   s7670  TV Show  World's Busiest Cities               NaN
# 7688   s7687    Movie  XV: Beyond the Tryline  Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu       James Brown
# 7740   s7739  TV Show         Young Wallander               NaN
#
#                                                    Cast         Country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# ...

# %% [markdown]
# ### Q. 10) In how many movies/shows, Tom Cruise was cast ?

# %%
df.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date    datetime64[ns]
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Year                   float64
# dtype: object

# %%
data = df.dropna()
# Creating new data fram without na values to filter on tom criuse because it rises an erro in the main dataframe baecause it has nan values (Cannot mask with non-boolean array containing NA / NaN values)

# %%
data[data['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#      Release_Date Rating Duration                        Type  \
# 3860   2020-01-01      R  189 min  Dramas, Independent Movies
# 5071   2019-07-01      R  134 min      Classic Movies, Dramas
#
#                                             Description    Year
# 3860  Through chance, human action, past history and...  2020.0
# 5071  A fast-talking yuppie is forced to slow down w...  2019.0

# %% [markdown]
# ### Q. 11) What are the different Ratings defined by Netflix ?

# %%
df.Rating.unique().tolist()
# Out:
# ['TV-MA',
#  'R',
#  'PG-13',
#  'TV-14',
#  'TV-PG',
#  'NR',
#  'TV-G',
#  'TV-Y',
#  nan,
#  'TV-Y7',
#  'PG',
#  'G',
#  'NC-17',
#  'TV-Y7-FV',
#  'UR']

# %% [markdown]
# ### Q. 11.1) How many Movies got the 'TV-14' rating, in Canada ?

# %%
# 1st solution
x = df[(df['Category'] == 'Movie') & (df['Country'] == 'Canada')].Rating.value_counts()
x
# Out:
# TV-MA    41
# R        16
# TV-PG    14
# TV-Y     12
# TV-14    11
# PG        8
# TV-G      6
# TV-Y7     3
# PG-13     3
# NR        2
# G         1
# NC-17     1
# Name: Rating, dtype: int64

# %%
sns.countplot(data=df[(df['Category'] == 'Movie') & (df['Country'] == 'Canada')],x = 'Rating',order=x.index)
plt.show()

# %%
df[(df['Category'] == 'Movie') & (df['Country'] == 'Canada') & (df.Rating == 'TV-14')].shape[0]
# Out:
# 11

# %% [markdown]
# ### Q. 11.2) How many TV Shows got the 'R' rating, after year 2018 ?

# %%
# 1st solution
x = df[(df['Category'] == 'TV Show') & (df['Year'] > 2018)].Rating.value_counts() # only 1 got R rating
x
# Out:
# TV-MA    657
# TV-14    346
# TV-PG    137
# TV-Y     108
# TV-Y7     83
# TV-G      50
# R          1
# Name: Rating, dtype: int64

# %%
sns.countplot(data=df[(df['Category'] == 'TV Show') & (df['Year'] > 2018)],x = 'Rating',order=x.index)
plt.show()

# %%
df[(df['Category'] == 'TV Show') & (df['Year'] > 2018) & (df.Rating == 'R')].shape[0]
# Out:
# 1

# %%
df[(df['Category'] == 'TV Show') & (df['Year'] > 2018) & (df.Rating == 'R')]
# Out:
#      Show_Id Category                                Title           Director  \
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country Release_Date  \
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN   2019-04-25
#
#      Rating  Duration      Type  \
# 6437      R  1 Season  TV Shows
#
#                                             Description    Year
# 6437  Trapped at a stagecoach stop as a storm rages ...  2019.0

# %% [markdown]
# ### Q. 12) What is the maximum duration of a Movie/Show on Netflix ?

# %%
movies = df[df['Category'] == 'Movie']
movies['Duration_mitues'] = movies['Duration'].apply(lambda x: int(x.split()[0])) #transform duration into integer to compare the durations

# %%
movies.dtypes
# Out:
# Show_Id            object
# Category           object
# Title              object
# Director           object
# Cast               object
# Country            object
# Release_Date       object
# Rating             object
# Duration           object
# Type               object
# Description        object
# Duration_mitues     int64
# dtype: object

# %%
#filter to get the max movie's duration 
movies[movies['Duration_mitues'] == movies.Duration_mitues.max()]
# Out:
#     Show_Id Category                       Title Director  \
# 957    s958    Movie  Black Mirror: Bandersnatch      NaN
#
#                                                   Cast        Country  \
# 957  Fionn Whitehead, Will Poulter, Craig Parkinson...  United States
#
#           Release_Date Rating Duration  \
# 957  December 28, 2018  TV-MA  312 min
#
#                                                Type  \
# 957  Dramas, International Movies, Sci-Fi & Fantasy
#
#                                            Description  Duration_mitues
# 957  In 1984, a young programmer begins to question...              312

# %%
tv_shows = df[df['Category'] == 'TV Show']

# %%
tv_shows['Duration_seasons'] = tv_shows['Duration'].apply(lambda x: int(x.split()[0])) #transform duration into integer to compare the durations

# %%
tv_shows.dtypes
# Out:
# Show_Id             object
# Category            object
# Title               object
# Director            object
# Cast                object
# Country             object
# Release_Date        object
# Rating              object
# Duration            object
# Type                object
# Description         object
# Duration_seasons     int64
# dtype: object

# %%
#filter to get the max TV Shows's duration 
tv_shows[tv_shows['Duration_seasons'] == tv_shows.Duration_seasons.max()]
# Out:
#      Show_Id Category           Title Director  \
# 2538   s2539  TV Show  Grey's Anatomy      NaN
#
#                                                    Cast        Country  \
# 2538  Ellen Pompeo, Sandra Oh, Katherine Heigl, Just...  United States
#
#      Release_Date Rating    Duration                          Type  \
# 2538  May 9, 2020  TV-14  16 Seasons  Romantic TV Shows, TV Dramas
#
#                                             Description  Duration_seasons
# 2538  Intern (and eventual resident) Meredith Grey f...                16

# %% [markdown]
# ### Q. 13) Which individual country has the Highest No. of TV Shows ?

# %%
df[df['Category'] == 'TV Show']['Country'].value_counts()
# Out:
# United States                                                705
# United Kingdom                                               204
# Japan                                                        157
# South Korea                                                  147
# India                                                         71
#                                                             ...
# Canada, United States, United Kingdom, France, Luxembourg      1
# United States, Italy                                           1
# Chile, Italy                                                   1
# Canada, United Kingdom                                         1
# United States, France, South Korea, Indonesia                  1
# Name: Country, Length: 183, dtype: int64

# %% [markdown]
# ### Q. 14) How can we sort the dataset by Year ?

# %%
df.sort_values(by = 'Year').head()
# Out:
#      Show_Id Category                        Title              Director  \
# 7115   s7114    Movie         To and From New York  Sorin Dan Mihalcescu
# 1765   s1766  TV Show              Dinner for Five                   NaN
# 3248   s3249    Movie      Just Another Love Story          Ole Bornedal
# 5766   s5766    Movie                     Splatter             Joe Dante
# 3840   s3841    Movie  Mad Ron's Prevues from Hell            Jim Monaco
#
#                                                    Cast        Country  \
# 7115  Barbara King, Shaana Diya, John Krisiukenas, Y...  United States
# 1765                                                NaN  United States
# 3248  Anders W. Berthelsen, Rebecka Hemse, Nikolaj L...        Denmark
# 5766  Corey Feldman, Tony Todd, Tara Leigh, Erin Way...  United States
# 3840  Nick Pawlow, Jordu Schell, Jay Kushwara, Micha...  United States
#
#      Release_Date Rating  Duration                                   Type  \
# ...

# %%
df.sort_values(by = 'Year',ascending=False).head()
# Out:
#      Show_Id Category             Title                 Director  \
# 5564   s5564    Movie   Sherlock Holmes              Guy Ritchie
# 5919   s5919    Movie         Surf's Up  Ash Brannon, Chris Buck
# 980     s981  TV Show      Bling Empire                      NaN
# 5955   s5955    Movie  Taare Zameen Par               Aamir Khan
# 366     s367    Movie         Al acecho      Francisco D'Eufemia
#
#                                                    Cast  \
# 5564  Robert Downey Jr., Jude Law, Rachel McAdams, M...
# 5919  Shia LaBeouf, Jeff Bridges, Zooey Deschanel, J...
# 980                                                 NaN
# 5955  Aamir Khan, Darsheel Safary, Tanay Chheda, Tis...
# 366   Rodrigo de la Serna, Belen Blanco, Walter Jako...
#
#                                                 Country Release_Date Rating  \
# 5564  United States, Germany, United Kingdom, Australia   2021-01-01  PG-13
# 5919                                      United States   2021-01-01     PG
# ...

# %% [markdown]
# ### Q. 15) Find all the instances where: Category is 'Movie' and Type is 'Dramas' or Category is 'TV Show' & Type is 'Kids' TV'.

# %%
df.Type.unique()
# Out:
# array(['International TV Shows, TV Dramas, TV Sci-Fi & Fantasy',
#        'Dramas, International Movies',
#        'Horror Movies, International Movies',
#        'Action & Adventure, Independent Movies, Sci-Fi & Fantasy',
#        'Dramas', 'International TV Shows, TV Dramas, TV Mysteries',
#        'Horror Movies, International Movies, Thrillers',
#        'Dramas, Thrillers',
#        'Crime TV Shows, International TV Shows, TV Dramas',
#        'Crime TV Shows, Docuseries, International TV Shows',
#        'Documentaries, International Movies, Sports Movies',
#        'Independent Movies, Sci-Fi & Fantasy, Thrillers',
#        'Dramas, International Movies, Thrillers',
#        'International TV Shows, TV Dramas',
#        'Comedies, Dramas, Independent Movies', 'Sports Movies',
#        'Dramas, Independent Movies, International Movies',
#        'Action & Adventure, Dramas, International Movies',
#        'Anime Series, International TV Shows', 'Documentaries',
# ...

# %%
df[((df['Category'] == 'Movie') & (df['Type'].str.contains('Dramas'))) | ((df['Category'] == 'TV Show') & (df['Type'].str.contains("Kids' TV")))]
# Out:
#      Show_Id Category        Title           Director  \
# 1         s2    Movie        07:19  Jorge Michel Grau
# 4         s5    Movie           21     Robert Luketic
# 7         s8    Movie          187     Kevin Reynolds
# 10       s11    Movie         1922       Zak Hilditch
# 15       s16    Movie       Oct-01     Kunle Afolayan
# ...      ...      ...          ...                ...
# 7778   s7777    Movie     Zokkomon   Satyajit Bhatkal
# 7779   s7778  TV Show  Zombie Dumb                NaN
# 7782   s7781    Movie          Zoo       Shlok Sharma
# 7784   s7783    Movie         Zozo        Josef Fares
# 7785   s7784    Movie       Zubaan        Mozez Singh
#
#                                                    Cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 7     Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# 10    Thomas Jane, Molly Parker, Dylan Schmid, Kaitl...
# ...

# %% [markdown]
# ### By Anas Awad
